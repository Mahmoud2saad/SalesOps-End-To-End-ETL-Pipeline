# %% [markdown]
# # These commands needs to be included inside a DAG's Python Operator

# %%
! pip install snowflake-cli
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# ...
#   Obtaining dependency information for snowflake-cli from https://files.pythonhosted.org/packages/7e/3f/82cad5f181e77bb55107e817eff32046de3e7bde54af7afe9430e6a5f2a2/snowflake_cli-3.16.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for click==8.1.8 from https://files.pythonhosted.org/packages/7e/d4/7ebdbd03970677812aac39c869717059dbb71a4cfc033ca6e5221787892c/click-8.1.8-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for gitpython==3.1.44 from https://files.pythonhosted.org/packages/1d/9a/4114a9057db2f1462d5c8f8390ab7383925fe1ac012eaa42402ad65c2963/GitPython-3.1.44-py3-none-any.whl.metadata
# ...

# %%
! snow --version
# Out:
# Snowflake CLI version: 3.16.0

# %%
! pip install snowflake-connector-python
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
sfOptions = {
    "sfURL": "KBBXLLH-XQ81200.snowflakecomputing.com",
    "sfUser": "IBRAHIMHEGAZI",
    "sfPassword": "ASDFqwer1234!",
    "sfDatabase": "YOUR_DB",
    "sfSchema": "GOLD",
    "sfWarehouse": "YOUR_WH",
    "sfRole": "ACCOUNTADMIN"
}

# %%
# !python "/home/jovyan/work/1) Scripts/8) Gold Initial Load.py"
# Out:
# 🔍 Testing Snowflake connection...
# ❌ Attempt 1 failed: 250001 (08001): Failed to connect to DB: KBBXLLH-XQ81200.snowflakecomputing.com:443. Your user account has been temporarily locked. Try again later or contact your account administrator for assistance. For more information about this error, go to https://community.snowflake.com/s/error-your-user-login-has-been-locked.
# ❌ Attempt 2 failed: 250001 (08001): Failed to connect to DB: KBBXLLH-XQ81200.snowflakecomputing.com:443. Your user account has been temporarily locked. Try again later or contact your account administrator for assistance. For more information about this error, go to https://community.snowflake.com/s/error-your-user-login-has-been-locked.
# ...
