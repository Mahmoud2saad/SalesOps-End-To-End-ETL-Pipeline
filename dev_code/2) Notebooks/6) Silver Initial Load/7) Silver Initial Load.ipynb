# %%
# !python "/home/jovyan/work/1) Scripts/6) Silver Initial Load.py"
# Out:
# 🚀 Starting Silver Layer Initial Load
# ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/29 17:08:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 🔧 Creating silver schema and tables
# ✅ Silver schema and tables created successfully!
#
# ...
# 📥 Loading silver.region from region.parquet...
# ...
#    📊 Records to load: 5
#    📋 Columns to load: r_regionkey, r_name
#    💾 Exporting to temporary CSV files...
#    📁 Exported to 1 CSV chunk(s)
#    🚀 Loading into PostgreSQL using COPY...
#    ✅ Successfully loaded 5 rows into silver.region
#    🔍 Verification: 5 rows in database
#    ✓ Row count matches source
#    🧹 Cleaned up temporary directory: /home/jovyan/work/temp_silver_export_region
#
# ...
# 📥 Loading silver.nation from nation.parquet...
# ...
#    📊 Records to load: 25
#    📋 Columns to load: n_nationkey, n_name, n_regionkey
# ...
