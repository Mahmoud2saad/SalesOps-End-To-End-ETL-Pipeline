# %%
#!python "/home/jovyan/work/1) Scripts/2) fast_initial_load_v1.py"

# %%
# !python "/home/jovyan/work/1) Scripts/2) fast_initial_load_v2.py"

# %%
# !python "/home/jovyan/work/1) Scripts/4) Bronze Initial Load.py"
# Out:
# 🚀 Starting ULTRA-FAST Initial Bulk Load
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/31 02:49:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 🔧 Resetting and initializing the control database schema...
# ✅ Control schema initialized successfully.
#
# ...
# ⚡ Bulk Loading bronze.region from region.parquet...
#    💾 Exporting 5 rows to temporary CSV chunks...
#    🚀 Injecting chunks directly into PostgreSQL using COPY...
#    📈 Calculating Max Value (r_regionkey) for watermark...
#    🔖 Explicitly Saving Watermark: 4
#    ✅ bronze.region bulk loaded successfully in RECORD TIME!
#    🧹 Smart Cleanup: Deleted temporary folder '/home/jovyan/work/temp_csv_export_region'
#
# ...
# ⚡ Bulk Loading bronze.nation from nation.parquet...
#    💾 Exporting 25 rows to temporary CSV chunks...
# ...
