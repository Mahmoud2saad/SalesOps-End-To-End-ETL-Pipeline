# %%
# !python "/home/jovyan/work/1) Scripts/7) Silver Incremental Load.py" 1996
# Out:
# 🚀 Starting Silver Layer Incremental Load for BATCH/YEAR 1996 ...
# ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/30 12:20:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# ...
# 🔍 Processing silver.orders from /home/jovyan/data/silver/increments/batch_1996/orders.parquet...
#    📌 Current Watermark: 1900-01-01
#    ⚡ Found 228626 NEW rows!
#    💾 Exporting to CSV...
#    🚀 Loading into PostgreSQL using COPY...
#    📈 Calculating NEW Max Value...
#    🔖 Updating Watermark to: 1996-12-31
#    ✅ Silver load for silver.orders completed!
#    🧹 Cleaned up temporary folder
#
# ...
# 🔍 Processing silver.lineitem from /home/jovyan/data/silver/increments/batch_1996/lineitem.parquet...
#    📌 Current Watermark: 1900-01-01
#    ⚡ Found 915491 NEW rows!
#    💾 Exporting to CSV...
#    🚀 Loading into PostgreSQL using COPY...
# ...

# %%
# !python "/home/jovyan/work/1) Scripts/7) Silver Incremental Load.py" 1997
# Out:
# 🚀 Starting Silver Layer Incremental Load for BATCH/YEAR 1997 ...
# ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/29 19:20:37 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# ...
# 🔍 Processing silver.orders from Batch 1997...
#    File: /home/jovyan/data/silver/increments/batch_1997/orders.parquet
#    📌 Current Watermark: 1996-12-31
#    ✓ Applied orders transformations
#    ⚡ Found 227,783 NEW rows!
#    📋 Columns to load: o_orderkey, o_custkey, o_orderstatus, o_totalprice, o_orderdate, o_orderpriority, o_clerk_id
#    💾 Exporting 227,783 rows to CSV...
#    🚀 Loading into PostgreSQL using COPY...
#    ✅ Loaded 227,783 rows into silver.orders
#    📈 Calculating new max value for o_orderdate...
#    🔖 Updating watermark to: 1997-12-31
#    ✅ Silver incremental load for silver.orders completed!
# ...

# %%
# !python "/home/jovyan/work/1) Scripts/7) Silver Incremental Load.py" 1998
# Out:
# 🚀 Starting Silver Layer Incremental Load for BATCH/YEAR 1998 ...
# ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/30 12:17:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# ...
# 🔍 Processing silver.orders from /home/jovyan/data/silver/increments/batch_1998/orders.parquet...
#    📌 Current Watermark: 1997-12-31
#    ⚡ Found 133623 NEW rows!
#    💾 Exporting to CSV...
#    🚀 Loading into PostgreSQL using COPY...
#    📈 Calculating NEW Max Value...
#    🔖 Updating Watermark to: 1998-08-02
#    ✅ Silver load for silver.orders completed!
#    🧹 Cleaned up temporary folder
#
# ...
# 🔍 Processing silver.lineitem from /home/jovyan/data/silver/increments/batch_1998/lineitem.parquet...
#    📌 Current Watermark: 1998-05-01
#    ⚡ Found 384788 NEW rows!
#    💾 Exporting to CSV...
#    🚀 Loading into PostgreSQL using COPY...
# ...
