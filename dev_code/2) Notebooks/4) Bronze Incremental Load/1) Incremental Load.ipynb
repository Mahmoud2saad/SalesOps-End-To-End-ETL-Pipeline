# %%
# !python "/home/jovyan/work/1) Scripts/3) fast_incremental_load.py" batch_1

# %%
#!python "/home/jovyan/work/1) Scripts/3) fast_incremental_load.py" batch_2

# %%
#!python "/home/jovyan/work/1) Scripts/3) fast_incremental_load.py" batch_3

# %%
# !python "/home/jovyan/work/1) Scripts/3) fast_incremental_load.py" batch_1

# %%
# !python "/home/jovyan/work/1) Scripts/5) Bronze Incremental Load.py" 1996
# Out:
# 🚀 Starting ULTRA-FAST Incremental Load for BATCH/YEAR 1996 ...
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/29 14:41:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#
# ...
# 🔓 REMOVING STRICT BRONZE FOREIGN KEYS
# ...
#    ✅ Bronze FK constraints dropped successfully.
#
# ...
# 🔍 Checking for NEW data in bronze.orders from Batch 1996...
#    📌 Current Watermark: 1995-12-31
#    ⚡ Found 228626 NEW rows! Exporting to CSV...
#    🚀 Injecting new data directly into PostgreSQL using COPY...
#    📈 Calculating NEW Max Value...
#    🔖 Updating Watermark to NEW Value: 1996-12-31
#    ✅ Incremental load for bronze.orders completed successfully!
#    🧹 Smart Cleanup: Deleted temporary folder '/home/jovyan/work/temp_csv_export_inc_orders'
#
# ...
# 🔍 Checking for NEW data in bronze.lineitem from Batch 1996...
# ...

# %%
# !python "/home/jovyan/work/1) Scripts/5) Bronze Incremental Load.py" 1997

# %%
# !python "/home/jovyan/work/1) Scripts/5) Bronze Incremental Load.py" 1998
